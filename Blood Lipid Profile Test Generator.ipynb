# %% [markdown]
# # Blood Lipid Profile Test Generator
#
# ### Description
#
# Number of Instances:
# 30000
#
# Data Set Characterstics :
# Multivariate
#
# Attribute Characterstics:
# Categorical, Real, Integer
#
# Associate Tasks:
# Classification
#
# Area:
# Life
#
# Number of Attributes:
# 14
#
#
#
# ### Source
#
# Creator:
#
# 1. Tamir Suliman tsulima2@gmu.edu
#
#
#
#
# ### Information
#
# This database contains attributes
#
#
# ### Attribute Information
#
# 1. age
# 2. sex
# 3. cp
# 4. tresbps
# 4. tchol
# 5. ldl
# 6. hdl
# 7. trigly
# 8. nonhdlc
# 9. tg2hdl
#
# 10. target ( predicted attribute )
#
#
#
# Complete attribute documentation:
#
# 1.  id: patient identification number
# 2.  age: age in years
# 3.  sex: sex (1 = male; 0 = female)
# 4.  cp: chest pain type
# 5. trestbps: resting blood pressure (in mm Hg on admission to the hospital)
# 6. tchol: total cholestrol in mg/dL
# 7. ldl: LDL cholestrol  in mg/dL
# 8. hdl: HDL Cholestrol in mg/dL
# 9. trigly: Triglycerides (
# 10. tg2hdl: TG to HDL ratio

# %%
## Cholesterol is measured in three categories:

# total cholesterol
# LDL, or ‘bad cholesterol”
# HDL, or ‘good cholesterol


import random
import numpy as np
import pandas as pd


N = 10000 # Number of Records
n = np.arange(0,N)

age = np.random.randint(18,70,size=N) # Age

sex = np.random.randint(2, size=N) # Sex Male = 1 , Female = 0
total_cholestrol = np.random.randint(125,245 ,size=N) # Total Chol. initialization 125 - 240 
ldl_cholestrol = np.random.randint(75,195, size=N)
chest_pain = np.random.randint(2, size=N)
exercise_tolerance = np.random.randint(3,size=N)
# Other attributes 
# Diabetic 
# hyber tensive
rawData = np.array([n, age, sex, total_cholestrol,ldl_cholestrol,chest_pain,exercise_tolerance])
# Hymaglobeen  normal ::  less :: function  - transfer oxygen to lee ansga  symptoms 
# Platlet count 
# Join all  data
df = pd.DataFrame({'no':n, 'age':age, 'sex':sex,'cp':chest_pain,'total-chol':total_cholestrol,'exerc':exercise_tolerance});
df.head(1000)
# Export generated data to CSV dataset file

df.to_csv(r'Blood_Lipid_Profile_Test_Fake_export.csv', index = False, header= True)
